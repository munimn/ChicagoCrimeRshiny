# %%
import pandas as pd

# %%
crimemeta = pd.read_csv("Crimes_-_2001_to_Present (2).csv")

# %%
display(crimemeta)
# Out:
#                ID Case Number                    Date                  Block  \
# 0        11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE
# 1        11645648    JC212959  01/01/2018 08:00:00 AM    024XX N MONITOR AVE
# 2        11645959    JC211511  12/20/2018 04:00:00 PM     045XX N ALBANY AVE
# 3        11645557    JC212685  04/01/2018 12:01:00 AM     080XX S VERNON AVE
# 4        11646293    JC213749  12/20/2018 03:00:00 PM   023XX N LOCKWOOD AVE
# ...           ...         ...                     ...                    ...
# 1400224     27322    JG131679  01/27/2023 02:06:00 PM    095XX S BENNETT AVE
# 1400225     27334    JG145885  02/08/2023 11:24:00 PM     025XX S WABASH AVE
# 1400226     27435    JG224023  04/15/2023 07:35:00 AM      005XX N LAMON AVE
# 1400227     27289    JG107068  01/06/2023 09:25:00 PM      056XX S THROOP ST
# 1400228     27577    JG307916  06/20/2023 12:42:00 PM     038XX W GLADYS AVE
#
# ...

# %%
crimemeta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400229 entries, 0 to 1400228
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ID                    1400229 non-null  int64
#  1   Case Number           1400229 non-null  object
#  2   Date                  1400229 non-null  object
#  3   Block                 1400229 non-null  object
#  4   IUCR                  1400229 non-null  object
#  5   Primary Type          1400229 non-null  object
#  6   Description           1400229 non-null  object
#  7   Location Description  1393220 non-null  object
#  8   Arrest                1400229 non-null  bool
#  9   Domestic              1400229 non-null  bool
#  10  Beat                  1400229 non-null  int64
#  11  District              1400229 non-null  int64
#  12  Ward                  1400177 non-null  float64
#  13  Community Area        1400227 non-null  float64
# ...

# %%
crimemeta.describe()
# Out:
#                  ID          Beat      District          Ward  Community Area  \
# count  1.400229e+06  1.400229e+06  1.400229e+06  1.400177e+06    1.400227e+06
# mean   1.217685e+07  1.146845e+03  1.123948e+01  2.324369e+01    3.669418e+01
# std    8.801690e+05  7.006896e+02  7.001552e+00  1.398565e+01    2.152395e+01
# min    2.375700e+04  1.110000e+02  1.000000e+00  1.000000e+00    1.000000e+00
# 25%    1.167691e+07  6.110000e+02  6.000000e+00  1.000000e+01    2.300000e+01
# 50%    1.220012e+07  1.031000e+03  1.000000e+01  2.400000e+01    3.200000e+01
# 75%    1.273974e+07  1.723000e+03  1.700000e+01  3.400000e+01    5.300000e+01
# max    1.325954e+07  2.535000e+03  3.100000e+01  5.000000e+01    7.700000e+01
#
#        X Coordinate  Y Coordinate          Year      Latitude     Longitude
# count  1.375309e+06  1.375309e+06  1.400229e+06  1.375309e+06  1.375309e+06
# mean   1.165129e+06  1.886352e+06  2.020369e+03  4.184374e+01 -8.766954e+01
# ...

# %%
crimemeta1 = crimemeta[['ID',"Primary Type","Description","Arrest","Community Area","Year","Date","Location Description","Domestic"]]

# %%
crimemeta2019= crimemeta1[(crimemeta1["Year"].isin([2021, 2022, 2020, 2019, 2018]))]

# %%
crimemeta2019= crimemeta2019[(crimemeta2019["Primary Type"].isin(["THEFT","BATTERY","CRIMINAL DAMAGE","ASSAULT","DECEPTIVE PRACTICE","WEAPONS VIOLATION","ROBBERY","NARCOTICS"]))]

# %%
crimemeta2019
# Out:
#                ID        Primary Type  \
# 0        11646166               THEFT
# 1        11645648  DECEPTIVE PRACTICE
# 3        11645557  DECEPTIVE PRACTICE
# 4        11646293  DECEPTIVE PRACTICE
# 5        11645568  DECEPTIVE PRACTICE
# ...           ...                 ...
# 1189759  13129282  DECEPTIVE PRACTICE
# 1189760  13128041  DECEPTIVE PRACTICE
# 1189761  13130030  DECEPTIVE PRACTICE
# 1189762  13128260  DECEPTIVE PRACTICE
# 1189763  13129286  DECEPTIVE PRACTICE
#
#                                      Description  Arrest  Community Area  \
# 0                                      OVER $500   False            44.0
# 1            FINANCIAL IDENTITY THEFT OVER $ 300   False            19.0
# 3            FINANCIAL IDENTITY THEFT OVER $ 300   False            44.0
# 4        FINANCIAL IDENTITY THEFT $300 AND UNDER   False            19.0
# 5            FINANCIAL IDENTITY THEFT OVER $ 300   False             6.0
# ...

# %%
crimemeta2019.describe()
# Out:
#                  ID  Community Area           Year
# count  9.369910e+05   936989.000000  936991.000000
# mean   1.204977e+07       36.407698    2019.893664
# std    5.091678e+05       21.503401       1.439807
# min    1.119221e+07        1.000000    2018.000000
# 25%    1.160210e+07       23.000000    2019.000000
# 50%    1.203810e+07       32.000000    2020.000000
# 75%    1.248949e+07       53.000000    2021.000000
# max    1.325904e+07       77.000000    2022.000000

# %%
geoids = pd.read_csv("CDStest_3246791987969808255.csv")

# %%
geoids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OBJECTID  77 non-null     int64
#  1   GEOID     77 non-null     int64
#  2   GEOG      77 non-null     object
#  3   TOT_POP   77 non-null     int64
#  4   POP_HH    77 non-null     int64
#  5   POP_GQ    77 non-null     int64
#  6   HISP      77 non-null     int64
#  7   WHITE     77 non-null     int64
#  8   BLACK     77 non-null     int64
#  9   ASIAN     77 non-null     int64
#  10  OTHER     77 non-null     int64
#  11  HU_TOT    77 non-null     int64
#  12  TOT_HH    77 non-null     int64
#  13  VAC_HU    77 non-null     int64
#  14  HH_SIZE   77 non-null     float64
# dtypes: float64(1), int64(13), object(1)
# memory usage: 9.1+ KB

# %%
geoids = geoids[["GEOID","GEOG"]]

# %%
# Assuming you have a DataFrame called df with a column 'OldName'
geoids.rename(columns={'GEOID': 'Community Area'}, inplace=True)

# %%
metageo = pd.merge(crimemeta2019, geoids, on='Community Area', how='left')

# %%
metageo = metageo.dropna()

# %%
metageo['Community Area'] = metageo['Community Area'].astype(int)
# Out:
# <ipython-input-86-8a7b8027528e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metageo['Community Area'] = metageo['Community Area'].astype(int)

# %%
metageo
# Out:
#               ID        Primary Type                              Description  \
# 0       11646166               THEFT                                OVER $500
# 1       11645648  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2       11645557  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       11646293  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4       11645568  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# ...          ...                 ...                                      ...
# 936983  13043918               THEFT                            FROM BUILDING
# 936984  13099981             BATTERY                                   SIMPLE
# 936985  13128926             BATTERY                  DOMESTIC BATTERY SIMPLE
# 936987  13128041  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 936988  13130030  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
# ...

# %%
metageo2018 = metageo[metageo["Year"] == 2018]
metageo2018.describe()
geo2018 = pd.read_csv("CDStest_-2640498170818431428.csv")
geo2018 = geo2018[["GEOG","TOT_POP","WHITE","HISP","BLACK","ASIAN","EMP","UNEMP","NOT_IN_LBFRC","MEDINC"]]
geo2018["Year"] = 2018
merged_df2018 = pd.merge(metageo2018, geo2018, on=['GEOG','Year'], how='left')
merged_df2018
# Out:
#               ID        Primary Type                              Description  \
# 0       11646166               THEFT                                OVER $500
# 1       11645648  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 2       11645557  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       11646293  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 4       11645568  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# ...          ...                 ...                                      ...
# 210829  12078409  DECEPTIVE PRACTICE                                  FORGERY
# 210830  12070026  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 210831  12185195  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 210832  12080837  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 210833  12006699  DECEPTIVE PRACTICE                              BOGUS CHECK
#
# ...

# %%
metageo2019 = metageo[metageo["Year"] == 2019]
metageo2019.describe()
geo2019 = pd.read_csv("CDStest_-7080538187671422812.csv")
geo2019 = geo2019[["GEOG","TOT_POP","WHITE","HISP","BLACK","ASIAN","EMP","UNEMP","NOT_IN_LBFRC","MEDINC"]]
geo2019["Year"] = 2019
merged_df2019 = pd.merge(metageo2019, geo2019, on=['GEOG','Year'], how='left')
merged_df2019
# Out:
#               ID        Primary Type  \
# 0       11641644               THEFT
# 1       11642710               THEFT
# 2       11642709               THEFT
# 3       11641640               THEFT
# 4       11644829               THEFT
# ...          ...                 ...
# 206505  12000492  DECEPTIVE PRACTICE
# 206506  12001484  DECEPTIVE PRACTICE
# 206507  12022897  DECEPTIVE PRACTICE
# 206508  12056523  DECEPTIVE PRACTICE
# 206509  12166069  DECEPTIVE PRACTICE
#
#                                               Description  Arrest  \
# 0                                           FROM BUILDING   False
# 1                                           FROM BUILDING   False
# 2                                           FROM BUILDING   False
# 3                                          $500 AND UNDER   False
# 4                                           FROM BUILDING   False
# ...                                                   ...     ...
# ...

# %%
metageo2020 = metageo[metageo["Year"] == 2020]
metageo2020.describe()
geo2020 = pd.read_csv("CDStest_9143891697026606298.csv")
geo2020 = geo2020[["GEOG","TOT_POP","WHITE","HISP","BLACK","ASIAN","EMP","UNEMP","NOT_IN_LBFRC","MEDINC"]]
geo2020["Year"] = 2020
merged_df2020 = pd.merge(metageo2020, geo2020, on=['GEOG','Year'], how='left')
merged_df2020
# Out:
#               ID        Primary Type                    Description  Arrest  \
# 0       12045583               THEFT                 $500 AND UNDER   False
# 1       12031001             BATTERY                         SIMPLE    True
# 2       12093529             ASSAULT           AGGRAVATED - HANDGUN    True
# 3       12178140             BATTERY                         SIMPLE   False
# 4       12126129   WEAPONS VIOLATION  UNLAWFUL POSSESSION - HANDGUN    True
# ...          ...                 ...                            ...     ...
# 166559  12165859     CRIMINAL DAMAGE    TO CITY OF CHICAGO PROPERTY   False
# 166560  12036199               THEFT                      OVER $500   False
# 166561  12082414               THEFT                 $500 AND UNDER   False
# 166562  12118237             BATTERY        DOMESTIC BATTERY SIMPLE   False
# 166563  12002171  DECEPTIVE PRACTICE              CREDIT CARD FRAUD   False
#
#         Community Area  Year                    Date  \
# ...

# %%
metageo2021 = metageo[metageo["Year"] == 2021]
metageo2021.describe()
geo2021 = pd.read_csv("CDStest_1743049070838230582.csv")
geo2021 = geo2021[["GEOG","TOT_POP","WHITE","HISP","BLACK","ASIAN","EMP","UNEMP","NOT_IN_LBFRC","MEDINC"]]
geo2021["Year"] = 2021
merged_df2021 = pd.merge(metageo2021, geo2021, on=['GEOG','Year'], how='left')
merged_df2021
# Out:
#               ID        Primary Type                          Description  \
# 0       12342615             ROBBERY                  VEHICULAR HIJACKING
# 1       13209369  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2       12374520             BATTERY              DOMESTIC BATTERY SIMPLE
# 3       13211146  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4       13185276  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# ...          ...                 ...                                  ...
# 165344  13104329               THEFT                            OVER $500
# 165345  13186125  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 165346  13196357               THEFT                        FROM BUILDING
# 165347  13151933               THEFT                            OVER $500
# 165348  13075828  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#         Arrest  Community Area  Year                    Date  \
# ...

# %%
metageo2022 = metageo[metageo["Year"] == 2022]
metageo2022.describe()
geo2022 = pd.read_csv("CDStest_8332829535412090510.csv")
geo2022 = geo2022[["GEOG","TOT_POP","WHITE","HISP","BLACK","ASIAN","EMP","UNEMP","NOT_IN_LBFRC","MEDINC"]]
geo2022["Year"] = 2022
merged_df2022 = pd.merge(metageo2022, geo2022, on=['GEOG','Year'], how='left')
merged_df2022
# Out:
#               ID        Primary Type                          Description  \
# 0       12888104   WEAPONS VIOLATION           RECKLESS FIREARM DISCHARGE
# 1       13209277               THEFT                            OVER $500
# 2       12622465             BATTERY              DOMESTIC BATTERY SIMPLE
# 3       12640859             BATTERY              DOMESTIC BATTERY SIMPLE
# 4       12671049             BATTERY              DOMESTIC BATTERY SIMPLE
# ...          ...                 ...                                  ...
# 181906  13043918               THEFT                        FROM BUILDING
# 181907  13099981             BATTERY                               SIMPLE
# 181908  13128926             BATTERY              DOMESTIC BATTERY SIMPLE
# 181909  13128041  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 181910  13130030  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#         Arrest  Community Area  Year                    Date  \
# ...

# %%
# Assuming you have two DataFrames df1 and df2
metadata = pd.concat([merged_df2022, merged_df2021,merged_df2020,merged_df2019,merged_df2018], axis=0)

# %%
metadata.describe()
# Out:
#                  ID  Community Area           Year        TOT_POP  \
# count  9.311680e+05   931168.000000  931168.000000  931168.000000
# mean   1.204899e+07       36.436944    2019.893674   47654.859697
# std    5.091657e+05       21.498043       1.440538   25574.304698
# min    1.119221e+07        1.000000    2018.000000    2006.000001
# 25%    1.160084e+07       23.000000    2019.000000   27503.000000
# 50%    1.203683e+07       32.000000    2020.000000   41106.000010
# 75%    1.248906e+07       53.000000    2021.000000   63170.000000
# max    1.325904e+07       77.000000    2022.000000  101428.000000
#
#                WHITE           HISP          BLACK          ASIAN  \
# count  931168.000000  931168.000000  931168.000000  931168.000000
# mean    14744.135796   10697.489575   18487.594963    2723.240013
# std     20289.536691   13719.398880   18839.561051    3946.693422
# min        10.000000       0.000000      42.000000       0.000000
# ...

# %%
metadata.to_csv('metadata.csv', index=False)
